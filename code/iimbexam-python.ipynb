# %%
import pandas as pd 
df=pd.read_csv('../inputdata/stanfordhealth.csv')
df.head(5)
# Out:
#    row.names  sbp  tobacco   ldl  adiposity  famhist  typea  obesity  alcohol  \
# 0          1  160    12.00  5.73      23.11  Present     49    25.30    97.20
# 1          2  144     0.01  4.41      28.61   Absent     55    28.87     2.06
# 2          3  118     0.08  3.48      32.28  Present     52    29.14     3.81
# 3          4  170     7.50  6.41      38.03  Present     51    31.99    24.26
# 4          5  134    13.60  3.50      27.78  Present     60    25.99    57.34
#
#    age  chd
# 0   52    1
# 1   63    1
# 2   46    0
# 3   58    1
# 4   49    1

# %%
#df.info()
df.shape
df.famhist.value_counts()
print(pd.crosstab(df.famhist, df.chd))
print(df.famhist.value_counts())
print(df.chd.value_counts())
print(df.columns)
# Out:
# chd        0   1
# famhist
# Absent   206  64
# Present   96  96
# famhist
# Absent     270
# Present    192
# Name: count, dtype: int64
# chd
# 0    302
# 1    160
# Name: count, dtype: int64
# Index(['row.names', 'sbp', 'tobacco', 'ldl', 'adiposity', 'famhist', 'typea',
#        'obesity', 'alcohol', 'age', 'chd'],
#       dtype='object')

# %%
import matplotlib.pyplot as pyp 
import seaborn as sb

pyp.scatter(x=df['ldl'],y=df['obesity'])
# Out:
# <Axes: xlabel='ldl', ylabel='obesity'>

# %%
sb.regplot(data=df,x='ldl',y='obesity')
# Out:
# <Axes: xlabel='ldl', ylabel='obesity'>

# %%
pyp.hist(df['age'],10)
# Out:
# (array([50., 17., 34., 42., 33., 51., 55., 50., 66., 64.]),
#  array([15. , 19.9, 24.8, 29.7, 34.6, 39.5, 44.4, 49.3, 54.2, 59.1, 64. ]),
#  <BarContainer object of 10 artists>)
