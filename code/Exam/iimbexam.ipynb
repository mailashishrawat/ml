# %%
import pandas as pd 
ds=pd.read_csv('../inputdata/imdb.csv')
updatedds=ds.dropna()
print (updatedds.count())
updatedds.to_csv('../out/iimb.csv')
# Out:
# <bound method DataFrame.count of       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4       NaN        Doug Walker                     NaN       NaN
# ...     ...                ...                     ...       ...
# 5038  Color        Scott Smith                     1.0      87.0
# 5039  Color                NaN                    43.0      43.0
# 5040  Color   Benjamin Roberds                    13.0      76.0
# 5041  Color        Daniel Hsia                    14.0     100.0
# 5042  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# ...

# %%
val G=1
val WE=2
val =45,490.50 + 3000.900 x G + 1497.89 WE – 990.75 G x WE

# %%
#updatedds=ds.dropna()
cnt= updatedds.count()
print(cnt)

#updatedds.head
# Out:
# color                        3755
# director_name                3755
# num_critic_for_reviews       3755
# duration                     3755
# director_facebook_likes      3755
# actor_3_facebook_likes       3755
# actor_2_name                 3755
# actor_1_facebook_likes       3755
# gross                        3755
# genres                       3755
# actor_1_name                 3755
# movie_title                  3755
# num_voted_users              3755
# cast_total_facebook_likes    3755
# actor_3_name                 3755
# facenumber_in_poster         3755
# plot_keywords                3755
# movie_imdb_link              3755
# num_user_for_reviews         3755
# language                     3755
# country                      3755
# content_rating               3755
# budget                       3755
# title_year                   3755
# actor_2_facebook_likes       3755
# imdb_score                   3755
# aspect_ratio                 3755
# ...

# %%
print("lets pivot")
#updatedds.columns
print(updatedds['genres'].values)

# updatedds[['Action','Adventure','Fantasy','Sci-Fi' ,'Action',
#  'Thriller' , 'Drama','Sci-Fi'
#  'Crime','Romance' 'Documentary']] = updatedds['genres'].str.split('| ', expand=True)
df=updatedds

list_genres = df.genres.apply(lambda x: x.split("|"))
genres = []
for row in list_genres:
    row = [genre.strip() for genre in row]
    for genre in row:
        if genre not in genres:
            genres.append(genre)

for genre in genres:
    df[genre] = df['genres'].str.contains(genre).astype(bool)

print(genres)


# updatedds.pivot_table(index=['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross',  'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes'],columns='genres', values="genres")
# Out:
# lets pivot
# ['Action|Adventure|Fantasy|Sci-Fi' 'Action|Adventure|Fantasy'
#  'Action|Adventure|Thriller' ... 'Drama|Sci-Fi|Thriller'
#  'Action|Crime|Drama|Romance|Thriller' 'Documentary']
# ['Action', 'Adventure', 'Fantasy', 'Sci-Fi', 'Thriller', 'Romance', 'Animation', 'Comedy', 'Family', 'Musical', 'Mystery', 'Western', 'Drama', 'History', 'Sport', 'Crime', 'Horror', 'War', 'Biography', 'Music', 'Documentary', 'Film-Noir']
# /var/folders/fl/jjn6m41x5390r7wk1j906b2c0000gr/T/ipykernel_5246/1955897047.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[genre] = df['genres'].str.contains(genre).astype(bool)
# /var/folders/fl/jjn6m41x5390r7wk1j906b2c0000gr/T/ipykernel_5246/1955897047.py:19: SettingWithCopyWarning:
# ...

# %%
df.head()
#df.to_csv('../out/iimb.csv')
df.to_excel('../out/imdbmovie.xlsx')
df.describe
# Out:
# <bound method NDFrame.describe of       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 5     Color     Andrew Stanton                   462.0     132.0
# ...     ...                ...                     ...       ...
# 5026  Color    Olivier Assayas                    81.0     110.0
# 5027  Color       Jafar Panahi                    64.0      90.0
# 5033  Color      Shane Carruth                   143.0      77.0
# 5035  Color   Robert Rodriguez                    56.0      81.0
# 5042  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes       actor_2_name  \
# 0                         0.0                   855.0   Joel David Moore
# ...

# %%
WE=1
# female G=1 /male G=0
G=1 
print ( "experience", "female", "male")
for WE in range(10):
    G=1
    rf =45490.50 + 3000.900*G + 1497.89 *WE- 990.75*G*WE
    G=0
    rm =45490.50 + 3000.900*G + 1497.89 *WE- 990.75*G*WE
  
    print ( WE  , "        ", rf, rm)
# Out:
# experience female male
# 0          48491.4 45490.5
# 1          48998.54 46988.39
# 2          49505.68 48486.28
# 3          50012.82 49984.17
# 4          50519.96 51482.06
# 5          51027.100000000006 52979.95
# 6          51534.240000000005 54477.84
# 7          52041.380000000005 55975.73
# 8          52548.520000000004 57473.62
# 9          53055.66 58971.51

# %%
import math
result=math.sqrt(.9)
result = -10.5 + 95*0.110
print(result)
# Out:
# 0.060516

# %%
marks=50
# male G=1 /female G=0
G=1 
print ( "experience", "male", "female")
for marks in range(100):
    G=1
    rf =96461.00 + 2441.89*marks+ 689.75*G*marks
    G=0
    rm =96461.00 + 2441.89*marks+ 689.75*G*marks
  
    print ( marks  , "        ", rf, rm)
# Out:
# experience male female
# 0          96461.0 96461.0
# 1          99592.64 98902.89
# 2          102724.28 101344.78
# 3          105855.92 103786.67
# 4          108987.56 106228.56
# 5          112119.2 108670.45
# 6          115250.84 111112.34
# 7          118382.48 113554.23
# 8          121514.12 115996.12
# 9          124645.76 118438.01
# 10          127777.4 120879.9
# 11          130909.04 123321.79
# 12          134040.68 125763.68
# 13          137172.32 128205.57
# 14          140303.96 130647.45999999999
# 15          143435.6 133089.35
# 16          146567.24 135531.24
# 17          149698.88 137973.13
# 18          152830.52 140415.02
# 19          155962.16 142856.91
# 20          159093.8 145298.8
# 21          162225.44 147740.69
# 22          165357.08 150182.58
# 23          168488.72 152624.47
# 24          171620.36 155066.36
# 25          174752.0 157508.25
# 26          177883.64 159950.14
# 27          181015.28 162392.03
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generating Xi values
Xi_values =np.arange(0, 10)   # You can adjust the range as per your requirement
#Xi_values =np.arange(100, 801, 100)
B0=-1.796 
B1=-.096
# Calculating corresponding Yi values
z=B0 + B1 * Xi_values

Yi_values = np.exp(z)/(1+np.exp(z))

print(np.exp(B1))
# Print Yi values
for i in range(len(Xi_values)):
    print(f"For Xi = {Xi_values[i]}, Yi = {Yi_values[i]}")
    
# Plotting the logarithmic chart
plt.figure(figsize=(8, 6))
plt.plot(Xi_values, Yi_values, label='Yi = np.exp(B0 + B1 * Xi_values)/(1+np.exp(B0 +B1 * Xi_values))', color='blue')
plt.title('Logarithmic Chart between Yi and -1.796 - 0.096Xi')
plt.xlabel('Xi')
plt.ylabel('Yi')
plt.ylim(0, 1) 
#plt.yscale('log')  # Setting y-axis to logarithmic scale
plt.grid(True)
plt.legend()
plt.show()
# Out:
# 0.9084640160687062
# For Xi = 0, Yi = 0.1423386801670364
# For Xi = 1, Yi = 0.13101659885419598
# For Xi = 2, Yi = 0.12046861351817797
# For Xi = 3, Yi = 0.1106616904867724
# For Xi = 4, Yi = 0.10156092789763664
# For Xi = 5, Yi = 0.09313023172022387
# For Xi = 6, Yi = 0.08533290751359307
# For Xi = 7, Yi = 0.07813216870533492
# For Xi = 8, Yi = 0.0714915646404644
# For Xi = 9, Yi = 0.06537533342557261

# %%
BlueCollar=-.627
Management=0
SelfEmployed=0
Unemployed=-0
Others=0
constnat=-1.916

# %%
import numpy as np


# Generating Xi values
Xi_values=0   # You can adjust the range as per your requirement

B0=.557
B1=.128
# Calculating corresponding Yi values
Yi_values = np.exp(B0 + B1 * Xi_values)/(1+np.exp(B0 +B1* Xi_values))

#print (Yi_values)

print("#For male ")
print (Yi_values)

print("for female ")
Xi_values=1
Yi_values = np.exp(B0 + B1 * Xi_values)/(1+np.exp(B0 +B1* Xi_values))
print(Yi_values)

print("for shift")
B1=.370
Xi_values=1
Yi_values = np.exp(B0 + B1 * Xi_values)/(1+np.exp(B0 +B1* Xi_values))
print(Yi_values)

print("for without shift")

B1=.370
Xi_values=0
Yi_values = np.exp(B0 + B1 * Xi_values)/(1+np.exp(B0 +B1* Xi_values))
print(Yi_values)
# Out:
# #For male
# 0.6357581144211154
# for female
# 0.6648537304059736
# for shift
# 0.7164662543716478
# for without shift
# 0.6357581144211154

# %%
import numpy as np


# Generating Xi values
   # You can adjust the range as per your requirement
FF=1
Perhike=10
shift=0
we=10
z=.367*FF+.245*Perhike+.365*shift-.004*we+.737
# Calculating corresponding Yi values
Yi_values = np.exp(z)/(1+np.exp(z))

#print (Yi_values)

print("#For 1st option ")
Yi_values = np.exp(z)/(1+np.exp(z))
print(Yi_values)

print ("#option2")
FF=0
Perhike=20
shift=1
we=2
z=.367*FF+.245*Perhike+.365*shift-.004*we+.737
# Calculating corresponding Yi values
Yi_values = np.exp(z)/(1+np.exp(z))
print(Yi_values)

print ("#option3")
FF=0
Perhike=15
shift=0
we=5
z=.367*FF+.245*Perhike+.365*shift-.004*we+.737
# Calculating corresponding Yi values
Yi_values = np.exp(z)/(1+np.exp(z))
print(Yi_values)

print ("#option4")
FF=1
Perhike=0
shift=1
we=6
z=.367*FF+.245*Perhike+.365*shift-.004*we+.737


# Calculating corresponding Yi values
Yi_values = np.exp(z)/(1+np.exp(z))
print(Yi_values)



#probabilyt of female willing to work 
print ("##probabilyt of female willing to work ")
FF=1
Perhike=0
shift=1
we=6
z=.370*1+.128*1+.557


# Calculating corresponding Yi values
Yi_values = np.exp(z)/(1+np.exp(z))
print(Yi_values)


#probabilyt of female willing to work 
print ("##campaign impact ")

campaign=0
z= campaign*-.096-1.796 


# Calculating corresponding Yi values
Yi_values = np.exp(z)/(1+np.exp(z))
print(Yi_values)
# Out:
# #For 1st option
# 0.9710834974176933
# #option2
# 0.9975125335223958
# #option3
# 0.9877753392741111
# #option4
# 0.809227736160078
# ##probabilyt of female willing to work
# 0.7417338799314313

# %%
def calculate_receptive_field(num_layers, kernel_size, stride):
    """
    Calculate the global receptive field for consecutive convolution layers.

    Args:
        num_layers (int): Number of convolution layers.
        kernel_size (int): Kernel size (assumed to be the same for all layers).
        stride (int): Stride (assumed to be the same for all layers).

    Returns:
        int: Global receptive field.
    """
    RF = 1  # Receptive field at input layer
    for _ in range(num_layers):
        RF += (kernel_size - 1) * stride
    return RF

# Example usage
num_layers = 4
kernel_size = 3
stride = 1
receptive_field = calculate_receptive_field(num_layers, kernel_size, stride)
print("Global Receptive Field:", receptive_field)  # Output: 11
# Out:
# Global Receptive Field: 9
